# %%
import numpy as np
import pandas as pn
import matplotlib.pyplot as mp 
# %matplotlib inline
import seaborn as sn

# %%
df = pn.read_csv('Random.csv', encoding='unicode_escape')

# %%
df.shape
# Out:
# (150, 8)

# %%
df.head()
# Out:
#   Firstname    Lastname        City       State        Date  Pitched Price  \
# 0      Jobi   McClimans     Abohar       PUNJAB  14-03-2023            325
# 1   Atlanta  Anestassia  Adityapur    JHARKHAND  18-05-2023             54
# 2   Jenilee     Kussell    Alandur   TAMIL NADU  13-10-2022            734
# 3     Caryl        Delp   Ambattur   TAMIL NADU  29-04-2023            691
# 4    Averyl       Macey      Ambur   TAMIL NADU  15-09-2022            225
#
#         Products           Color
# 0        Replica          Yellow
# 1    Decoratives  Red and Yellow
# 2  Logo/keychain   Red and Black
# 3        Replica         Orrange
# 4      Batmobile         Orrange

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Firstname      150 non-null    object
#  1   Lastname       150 non-null    object
#  2   City           150 non-null    object
#  3   State          150 non-null    object
#  4   Date           150 non-null    object
#  5   Pitched Price  150 non-null    int64
#  6   Products       150 non-null    object
#  7   Color          150 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 9.5+ KB

# %%
pn.isnull(df).sum()
# Out:
# Firstname        0
# Lastname         0
# City             0
# State            0
# Date             0
# Pitched Price    0
# Products         0
# Color            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Firstname', 'Lastname', 'City', 'State', 'Date', 'Pitched Price',
#        'Products', 'Color'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Firstname', 'Lastname', 'City', 'State', 'Date', 'Pitched Price',
#        'Products', 'Color'],
#       dtype='object')

# %%
df[['Pitched Price']].describe()
# Out:
#        Pitched Price
# count     150.000000
# mean      518.966667
# std       276.852623
# min        54.000000
# 25%       308.500000
# 50%       468.500000
# 75%       770.500000
# max       995.000000

# %%
df.columns
# Out:
# Index(['Firstname', 'Lastname', 'City', 'State', 'Date', 'Pitched Price',
#        'Products', 'Color'],
#       dtype='object')

# %%
fig1 ,ax1 = mp.subplots(figsize=(15,5))
cl = sn.countplot(x= 'Color', data = df)
for bars in cl.containers:
    cl.bar_label(bars)

# %%
fig1 ,ax1 = mp.subplots(figsize=(15,5))
ov = sn.countplot(x='Products',data =df , hue ='Color')
for bars in ov.containers:
    ov.bar_label(bars)

# %%
df.rename(columns={'Batmobile':'Batarangs'})
# Out:
#       Firstname    Lastname                City        State        Date  \
# 0          Jobi   McClimans             Abohar        PUNJAB  14-03-2023
# 1       Atlanta  Anestassia          Adityapur     JHARKHAND  18-05-2023
# 2       Jenilee     Kussell            Alandur    TAMIL NADU  13-10-2022
# 3         Caryl        Delp           Ambattur    TAMIL NADU  29-04-2023
# 4        Averyl       Macey              Ambur    TAMIL NADU  15-09-2022
# ..          ...         ...                 ...          ...         ...
# 145      Wileen  Anestassia       Tiruvottiyur    TAMIL NADU  21-12-2022
# 146   Kara-Lynn       Amand           Titagarh   WEST BENGAL  30-04-2023
# 147      Dorene      Jammal           Uluberia   WEST BENGAL  03-02-2022
# 148       Coral     Jillane  Uttarpara Kotrung   WEST BENGAL  25-01-2022
# 149  Marcelline      Viddah            Vellore    TAMIL NADU  23-12-2022
#
#      Pitched Price       Products           Color
# 0              325        Replica          Yellow
# 1               54    Decoratives  Red and Yellow
# 2              734  Logo/keychain   Red and Black
# 3              691        Replica         Orrange
# 4              225      Batmobile         Orrange
# ..             ...            ...             ...
# 145            440    Decoratives            Blue
# 146            775       Batarang            Blue
# 147            325  Action Figure  Red and Yellow
# 148            306    Decoratives           Multi
# 149            388  Logo/keychain           Green
#
# [150 rows x 8 columns]

# %%
fig1 ,ax1 = mp.subplots(figsize=(12,5))
sales_product = df.groupby(['Products'], as_index=False)['Pitched Price'].sum().sort_values(by='Pitched Price',ascending=False)

ad = sn.barplot(x='Products',y='Pitched Price',data=sales_product)

for bars in ad.containers:
    ad.bar_label(bars)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Firstname      150 non-null    object
#  1   Lastname       150 non-null    object
#  2   City           150 non-null    object
#  3   State          150 non-null    object
#  4   Date           150 non-null    object
#  5   Pitched Price  150 non-null    int64
#  6   Products       150 non-null    object
#  7   Color          150 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 9.5+ KB

# %%
fig1 ,ax1 = mp.subplots(figsize=(12,4))
ac= df.groupby('Firstname')['Pitched Price'].sum().sort_values(ascending =False).nlargest(10).plot(kind='bar')
for bars in ac.containers:
    ac.bar_label(bars)
